# %%
from utils.MysqlProcessor import MysqlProcessor

# %%
processor = MysqlProcessor()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x7940687e5e10>

# %%
processor.execute(sql="CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
results = processor.fetchAll(sql="select * from ORDERS")
for row in results:
    print(row)
# Out:
# (1, datetime.date(2024, 5, 1), Decimal('58.0000'))
# (2, datetime.date(2024, 5, 1), Decimal('99.0000'))
# (3, datetime.date(2024, 5, 1), Decimal('31.0000'))
# (1, datetime.date(2024, 5, 2), Decimal('48.0000'))
# (2, datetime.date(2024, 5, 2), Decimal('25.0000'))
# (3, datetime.date(2024, 5, 2), Decimal('58.0000'))
# (1, datetime.date(2024, 5, 3), Decimal('37.0000'))
# (2, datetime.date(2024, 5, 3), Decimal('74.0000'))
# (3, datetime.date(2024, 5, 3), Decimal('56.0000'))
# (1, datetime.date(2024, 5, 4), Decimal('67.0000'))
# (2, datetime.date(2024, 5, 4), Decimal('42.0000'))
# (3, datetime.date(2024, 5, 4), Decimal('89.0000'))
# (1, datetime.date(2024, 5, 5), Decimal('42.0000'))
# (2, datetime.date(2024, 5, 5), Decimal('102.0000'))
# (3, datetime.date(2024, 5, 5), Decimal('92.0000'))
# (1, datetime.date(2024, 5, 6), Decimal('64.0000'))
# (2, datetime.date(2024, 5, 6), Decimal('16.0000'))
# (3, datetime.date(2024, 5, 6), Decimal('55.0000'))
# (1, datetime.date(2024, 5, 7), Decimal('51.0000'))
# (2, datetime.date(2024, 5, 7), Decimal('60.0000'))
# (3, datetime.date(2024, 5, 7), Decimal('40.0000'))
# (1, datetime.date(2024, 5, 8), Decimal('24.0000'))
# (2, datetime.date(2024, 5, 8), Decimal('66.0000'))
# (3, datetime.date(2024, 5, 8), Decimal('55.0000'))
# (1, datetime.date(2024, 5, 9), Decimal('84.0000'))
# (2, datetime.date(2024, 5, 9), Decimal('36.0000'))
# (3, datetime.date(2024, 5, 9), Decimal('98.0000'))
# (1, datetime.date(2024, 5, 10), Decimal('17.0000'))
# (2, datetime.date(2024, 5, 10), Decimal('42.0000'))
# (3, datetime.date(2024, 5, 10), Decimal('51.0000'))
# (1, datetime.date(2024, 5, 11), Decimal('41.0000'))
# (2, datetime.date(2024, 5, 11), Decimal('21.0000'))
# (3, datetime.date(2024, 5, 11), Decimal('59.0000'))
# (1, datetime.date(2024, 5, 12), Decimal('55.0000'))
# (2, datetime.date(2024, 5, 12), Decimal('68.0000'))
# (3, datetime.date(2024, 5, 12), Decimal('65.0000'))
# (1, datetime.date(2024, 5, 13), Decimal('34.0000'))
# (2, datetime.date(2024, 5, 13), Decimal('39.0000'))
# (3, datetime.date(2024, 5, 13), Decimal('75.0000'))
# (1, datetime.date(2024, 5, 14), Decimal('80.0000'))
# (2, datetime.date(2024, 5, 14), Decimal('52.0000'))
# (3, datetime.date(2024, 5, 14), Decimal('99.0000'))
# (1, datetime.date(2024, 5, 15), Decimal('65.0000'))
# (2, datetime.date(2024, 5, 15), Decimal('92.0000'))
# (3, datetime.date(2024, 5, 15), Decimal('63.0000'))
# (1, datetime.date(2024, 5, 16), Decimal('45.0000'))
# (2, datetime.date(2024, 5, 16), Decimal('99.0000'))
# (3, datetime.date(2024, 5, 16), Decimal('66.0000'))
# (1, datetime.date(2024, 5, 17), Decimal('40.0000'))
# (2, datetime.date(2024, 5, 17), Decimal('66.0000'))
# (3, datetime.date(2024, 5, 17), Decimal('102.0000'))
# (1, datetime.date(2024, 5, 18), Decimal('38.0000'))
# (2, datetime.date(2024, 5, 18), Decimal('40.0000'))
# (3, datetime.date(2024, 5, 18), Decimal('71.0000'))
# (1, datetime.date(2024, 5, 19), Decimal('55.0000'))
# (2, datetime.date(2024, 5, 19), Decimal('32.0000'))
# (3, datetime.date(2024, 5, 19), Decimal('73.0000'))
# (1, datetime.date(2024, 5, 20), Decimal('89.0000'))
# (2, datetime.date(2024, 5, 20), Decimal('99.0000'))
# (3, datetime.date(2024, 5, 20), Decimal('33.0000'))
# (1, datetime.date(2024, 5, 21), Decimal('59.0000'))
# (2, datetime.date(2024, 5, 21), Decimal('72.0000'))
# (3, datetime.date(2024, 5, 21), Decimal('75.0000'))
# (1, datetime.date(2024, 5, 22), Decimal('72.0000'))
# (2, datetime.date(2024, 5, 22), Decimal('103.0000'))
# (3, datetime.date(2024, 5, 22), Decimal('103.0000'))
# (1, datetime.date(2024, 5, 23), Decimal('23.0000'))
# (2, datetime.date(2024, 5, 23), Decimal('56.0000'))
# (3, datetime.date(2024, 5, 23), Decimal('102.0000'))
# (1, datetime.date(2024, 5, 24), Decimal('67.0000'))
# (2, datetime.date(2024, 5, 24), Decimal('94.0000'))
# (3, datetime.date(2024, 5, 24), Decimal('69.0000'))
# (1, datetime.date(2024, 5, 25), Decimal('67.0000'))
# (2, datetime.date(2024, 5, 25), Decimal('96.0000'))
# (3, datetime.date(2024, 5, 25), Decimal('82.0000'))
# (1, datetime.date(2024, 5, 26), Decimal('34.0000'))
# (2, datetime.date(2024, 5, 26), Decimal('82.0000'))
# (3, datetime.date(2024, 5, 26), Decimal('11.0000'))
# (1, datetime.date(2024, 5, 27), Decimal('97.0000'))
# (2, datetime.date(2024, 5, 27), Decimal('47.0000'))
# (3, datetime.date(2024, 5, 27), Decimal('20.0000'))
# (1, datetime.date(2024, 5, 28), Decimal('63.0000'))
# (2, datetime.date(2024, 5, 28), Decimal('37.0000'))
# (3, datetime.date(2024, 5, 28), Decimal('71.0000'))
# (1, datetime.date(2024, 5, 29), Decimal('66.0000'))
# (2, datetime.date(2024, 5, 29), Decimal('85.0000'))
# (3, datetime.date(2024, 5, 29), Decimal('27.0000'))
# (1, datetime.date(2024, 5, 30), Decimal('74.0000'))
# (2, datetime.date(2024, 5, 30), Decimal('70.0000'))
# (3, datetime.date(2024, 5, 30), Decimal('22.0000'))
# (1, datetime.date(2024, 5, 31), Decimal('95.0000'))
# (2, datetime.date(2024, 5, 31), Decimal('94.0000'))
# (3, datetime.date(2024, 5, 31), Decimal('82.0000'))
# (1, datetime.date(2024, 6, 1), Decimal('39.0000'))
# (2, datetime.date(2024, 6, 1), Decimal('105.0000'))
# (3, datetime.date(2024, 6, 1), Decimal('22.0000'))
# (1, datetime.date(2024, 6, 2), Decimal('82.0000'))
# (2, datetime.date(2024, 6, 2), Decimal('34.0000'))
# (3, datetime.date(2024, 6, 2), Decimal('94.0000'))
# (1, datetime.date(2024, 6, 3), Decimal('93.0000'))
# (2, datetime.date(2024, 6, 3), Decimal('59.0000'))
# (3, datetime.date(2024, 6, 3), Decimal('98.0000'))
# (1, datetime.date(2024, 6, 4), Decimal('36.0000'))
# (2, datetime.date(2024, 6, 4), Decimal('44.0000'))
# (3, datetime.date(2024, 6, 4), Decimal('96.0000'))
# (1, datetime.date(2024, 6, 5), Decimal('74.0000'))
# (2, datetime.date(2024, 6, 5), Decimal('54.0000'))
# (3, datetime.date(2024, 6, 5), Decimal('32.0000'))
# (1, datetime.date(2024, 6, 6), Decimal('98.0000'))
# (2, datetime.date(2024, 6, 6), Decimal('84.0000'))
# (3, datetime.date(2024, 6, 6), Decimal('19.0000'))
# (1, datetime.date(2024, 6, 7), Decimal('38.0000'))
# (2, datetime.date(2024, 6, 7), Decimal('100.0000'))
# (3, datetime.date(2024, 6, 7), Decimal('96.0000'))
# (1, datetime.date(2024, 6, 8), Decimal('91.0000'))
# (2, datetime.date(2024, 6, 8), Decimal('41.0000'))
# (3, datetime.date(2024, 6, 8), Decimal('11.0000'))
# (1, datetime.date(2024, 6, 9), Decimal('33.0000'))
# (2, datetime.date(2024, 6, 9), Decimal('103.0000'))
# (3, datetime.date(2024, 6, 9), Decimal('29.0000'))
# (1, datetime.date(2024, 6, 10), Decimal('27.0000'))
# (2, datetime.date(2024, 6, 10), Decimal('20.0000'))
# (3, datetime.date(2024, 6, 10), Decimal('92.0000'))
# (1, datetime.date(2024, 6, 11), Decimal('35.0000'))
# (2, datetime.date(2024, 6, 11), Decimal('58.0000'))
# (3, datetime.date(2024, 6, 11), Decimal('76.0000'))
# (1, datetime.date(2024, 6, 12), Decimal('25.0000'))
# (2, datetime.date(2024, 6, 12), Decimal('56.0000'))
# (3, datetime.date(2024, 6, 12), Decimal('96.0000'))
# (1, datetime.date(2024, 6, 13), Decimal('36.0000'))
# (2, datetime.date(2024, 6, 13), Decimal('49.0000'))
# (3, datetime.date(2024, 6, 13), Decimal('29.0000'))
# (1, datetime.date(2024, 6, 14), Decimal('100.0000'))
# (2, datetime.date(2024, 6, 14), Decimal('101.0000'))
# (3, datetime.date(2024, 6, 14), Decimal('101.0000'))
# (1, datetime.date(2024, 6, 15), Decimal('17.0000'))
# (2, datetime.date(2024, 6, 15), Decimal('37.0000'))
# (3, datetime.date(2024, 6, 15), Decimal('21.0000'))
# (1, datetime.date(2024, 6, 16), Decimal('96.0000'))
# (2, datetime.date(2024, 6, 16), Decimal('105.0000'))
# (3, datetime.date(2024, 6, 16), Decimal('40.0000'))
# (1, datetime.date(2024, 6, 17), Decimal('76.0000'))
# (2, datetime.date(2024, 6, 17), Decimal('41.0000'))
# (3, datetime.date(2024, 6, 17), Decimal('57.0000'))
# (1, datetime.date(2024, 6, 18), Decimal('76.0000'))
# (2, datetime.date(2024, 6, 18), Decimal('84.0000'))
# (3, datetime.date(2024, 6, 18), Decimal('85.0000'))
# (1, datetime.date(2024, 6, 19), Decimal('84.0000'))
# (2, datetime.date(2024, 6, 19), Decimal('42.0000'))
# (3, datetime.date(2024, 6, 19), Decimal('35.0000'))
# (1, datetime.date(2024, 6, 20), Decimal('58.0000'))
# (2, datetime.date(2024, 6, 20), Decimal('59.0000'))
# (3, datetime.date(2024, 6, 20), Decimal('15.0000'))
# (1, datetime.date(2024, 6, 21), Decimal('92.0000'))
# (2, datetime.date(2024, 6, 21), Decimal('102.0000'))
# (3, datetime.date(2024, 6, 21), Decimal('37.0000'))
# (1, datetime.date(2024, 6, 22), Decimal('72.0000'))
# (2, datetime.date(2024, 6, 22), Decimal('29.0000'))
# (3, datetime.date(2024, 6, 22), Decimal('102.0000'))
# (1, datetime.date(2024, 6, 23), Decimal('55.0000'))
# (2, datetime.date(2024, 6, 23), Decimal('35.0000'))
# (3, datetime.date(2024, 6, 23), Decimal('86.0000'))
# (1, datetime.date(2024, 6, 24), Decimal('52.0000'))
# (2, datetime.date(2024, 6, 24), Decimal('67.0000'))
# (3, datetime.date(2024, 6, 24), Decimal('70.0000'))
# (1, datetime.date(2024, 6, 25), Decimal('64.0000'))
# (2, datetime.date(2024, 6, 25), Decimal('78.0000'))
# (3, datetime.date(2024, 6, 25), Decimal('92.0000'))
# (1, datetime.date(2024, 6, 26), Decimal('46.0000'))
# (2, datetime.date(2024, 6, 26), Decimal('15.0000'))
# (3, datetime.date(2024, 6, 26), Decimal('14.0000'))
# (1, datetime.date(2024, 6, 27), Decimal('33.0000'))
# (2, datetime.date(2024, 6, 27), Decimal('95.0000'))
# (3, datetime.date(2024, 6, 27), Decimal('80.0000'))
# (1, datetime.date(2024, 6, 28), Decimal('29.0000'))
# (2, datetime.date(2024, 6, 28), Decimal('62.0000'))
# (3, datetime.date(2024, 6, 28), Decimal('20.0000'))
# (1, datetime.date(2024, 6, 29), Decimal('18.0000'))
# (2, datetime.date(2024, 6, 29), Decimal('89.0000'))
# (3, datetime.date(2024, 6, 29), Decimal('101.0000'))
# (1, datetime.date(2024, 6, 30), Decimal('53.0000'))
# (2, datetime.date(2024, 6, 30), Decimal('29.0000'))
# (3, datetime.date(2024, 6, 30), Decimal('61.0000'))
# (1, datetime.date(2024, 7, 1), Decimal('38.0000'))
# (2, datetime.date(2024, 7, 1), Decimal('73.0000'))
# (3, datetime.date(2024, 7, 1), Decimal('49.0000'))
# (1, datetime.date(2024, 7, 2), Decimal('31.0000'))
# (2, datetime.date(2024, 7, 2), Decimal('73.0000'))
# (3, datetime.date(2024, 7, 2), Decimal('70.0000'))
# (1, datetime.date(2024, 7, 3), Decimal('43.0000'))
# (2, datetime.date(2024, 7, 3), Decimal('67.0000'))
# (3, datetime.date(2024, 7, 3), Decimal('101.0000'))
# (1, datetime.date(2024, 7, 4), Decimal('30.0000'))
# (2, datetime.date(2024, 7, 4), Decimal('96.0000'))
# (3, datetime.date(2024, 7, 4), Decimal('95.0000'))
# (1, datetime.date(2024, 7, 5), Decimal('102.0000'))
# (2, datetime.date(2024, 7, 5), Decimal('99.0000'))
# (3, datetime.date(2024, 7, 5), Decimal('83.0000'))
# (1, datetime.date(2024, 7, 6), Decimal('28.0000'))
# (2, datetime.date(2024, 7, 6), Decimal('50.0000'))
# (3, datetime.date(2024, 7, 6), Decimal('57.0000'))
# (1, datetime.date(2024, 7, 7), Decimal('47.0000'))
# (2, datetime.date(2024, 7, 7), Decimal('34.0000'))
# (3, datetime.date(2024, 7, 7), Decimal('14.0000'))
# (1, datetime.date(2024, 7, 8), Decimal('71.0000'))
# (2, datetime.date(2024, 7, 8), Decimal('94.0000'))
# (3, datetime.date(2024, 7, 8), Decimal('58.0000'))
# (1, datetime.date(2024, 7, 9), Decimal('106.0000'))
# (2, datetime.date(2024, 7, 9), Decimal('44.0000'))
# (3, datetime.date(2024, 7, 9), Decimal('75.0000'))
# (1, datetime.date(2024, 7, 10), Decimal('61.0000'))
# (2, datetime.date(2024, 7, 10), Decimal('52.0000'))
# (3, datetime.date(2024, 7, 10), Decimal('62.0000'))
# (1, datetime.date(2024, 7, 11), Decimal('69.0000'))
# (2, datetime.date(2024, 7, 11), Decimal('33.0000'))
# (3, datetime.date(2024, 7, 11), Decimal('34.0000'))
# (1, datetime.date(2024, 7, 12), Decimal('82.0000'))
# (2, datetime.date(2024, 7, 12), Decimal('90.0000'))
# (3, datetime.date(2024, 7, 12), Decimal('97.0000'))
# (1, datetime.date(2024, 7, 13), Decimal('34.0000'))
# (2, datetime.date(2024, 7, 13), Decimal('34.0000'))
# (3, datetime.date(2024, 7, 13), Decimal('53.0000'))
# (1, datetime.date(2024, 7, 14), Decimal('78.0000'))
# (2, datetime.date(2024, 7, 14), Decimal('105.0000'))
# (3, datetime.date(2024, 7, 14), Decimal('93.0000'))
# (1, datetime.date(2024, 7, 15), Decimal('61.0000'))
# (2, datetime.date(2024, 7, 15), Decimal('88.0000'))
# (3, datetime.date(2024, 7, 15), Decimal('56.0000'))
# (1, datetime.date(2024, 7, 16), Decimal('24.0000'))
# (2, datetime.date(2024, 7, 16), Decimal('106.0000'))
# (3, datetime.date(2024, 7, 16), Decimal('76.0000'))
# (1, datetime.date(2024, 7, 17), Decimal('64.0000'))
# (2, datetime.date(2024, 7, 17), Decimal('61.0000'))
# (3, datetime.date(2024, 7, 17), Decimal('100.0000'))
# (1, datetime.date(2024, 7, 18), Decimal('43.0000'))
# (2, datetime.date(2024, 7, 18), Decimal('70.0000'))
# (3, datetime.date(2024, 7, 18), Decimal('23.0000'))
# (1, datetime.date(2024, 7, 19), Decimal('97.0000'))
# (2, datetime.date(2024, 7, 19), Decimal('104.0000'))
# (3, datetime.date(2024, 7, 19), Decimal('32.0000'))
# (1, datetime.date(2024, 7, 20), Decimal('41.0000'))
# (2, datetime.date(2024, 7, 20), Decimal('77.0000'))
# (3, datetime.date(2024, 7, 20), Decimal('62.0000'))
# (1, datetime.date(2024, 7, 21), Decimal('86.0000'))
# (2, datetime.date(2024, 7, 21), Decimal('27.0000'))
# (3, datetime.date(2024, 7, 21), Decimal('46.0000'))
# (1, datetime.date(2024, 7, 22), Decimal('63.0000'))
# (2, datetime.date(2024, 7, 22), Decimal('53.0000'))
# (3, datetime.date(2024, 7, 22), Decimal('60.0000'))
# (1, datetime.date(2024, 7, 23), Decimal('55.0000'))
# (2, datetime.date(2024, 7, 23), Decimal('65.0000'))
# (3, datetime.date(2024, 7, 23), Decimal('52.0000'))
# (1, datetime.date(2024, 7, 24), Decimal('73.0000'))
# (2, datetime.date(2024, 7, 24), Decimal('84.0000'))
# (3, datetime.date(2024, 7, 24), Decimal('93.0000'))
# (1, datetime.date(2024, 7, 25), Decimal('33.0000'))
# (2, datetime.date(2024, 7, 25), Decimal('43.0000'))
# (3, datetime.date(2024, 7, 25), Decimal('98.0000'))
# (1, datetime.date(2024, 7, 26), Decimal('87.0000'))
# (2, datetime.date(2024, 7, 26), Decimal('19.0000'))
# (3, datetime.date(2024, 7, 26), Decimal('98.0000'))
# (1, datetime.date(2024, 7, 27), Decimal('66.0000'))
# (2, datetime.date(2024, 7, 27), Decimal('99.0000'))
# (3, datetime.date(2024, 7, 27), Decimal('99.0000'))
# (1, datetime.date(2024, 7, 28), Decimal('108.0000'))
# (2, datetime.date(2024, 7, 28), Decimal('24.0000'))
# (3, datetime.date(2024, 7, 28), Decimal('61.0000'))
# (1, datetime.date(2024, 7, 29), Decimal('57.0000'))
# (2, datetime.date(2024, 7, 29), Decimal('69.0000'))
# (3, datetime.date(2024, 7, 29), Decimal('68.0000'))
# (1, datetime.date(2024, 7, 30), Decimal('45.0000'))
# (2, datetime.date(2024, 7, 30), Decimal('84.0000'))
# (3, datetime.date(2024, 7, 30), Decimal('85.0000'))
# (1, datetime.date(2024, 7, 31), Decimal('86.0000'))
# (2, datetime.date(2024, 7, 31), Decimal('50.0000'))
# (3, datetime.date(2024, 7, 31), Decimal('69.0000'))

# %%
import smtplib
from email.message import EmailMessage

# Setup credentials
email_address = "brijeshdhaker@gmail.com"
app_password = "kypa ftth zhgc xhxk"

# Create the email
msg = EmailMessage()
msg['Subject'] = "Python Test Email"
msg['From'] = email_address
msg['To'] = "brijeshdhaker@gmail.com"
msg.set_content("This is a test email sent from Python!")

# Send via Gmail's SMTP server
try:
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
        smtp.login(email_address, app_password)
        smtp.send_message(msg)
    print("Email sent successfully!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-2b274756621sm109787185ad.20 - gsmtp')

# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = [
  "https://www.googleapis.com/auth/gmail.readonly",
  "https://www.googleapis.com/auth/gmail.send",
  "https://www.googleapis.com/auth/gmail.compose",
  "https://mail.google.com/"
]


def main():
  """Shows basic usage of the Gmail API.
  Lists the user's Gmail labels.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    # Call the Gmail API
    service = build("gmail", "v1", credentials=creds)
    results = service.users().labels().list(userId="me").execute()
    labels = results.get("labels", [])

    if not labels:
      print("No labels found.")
      return
    print("Labels:")
    for label in labels:
      print(label["name"])

  except HttpError as error:
    # TODO(developer) - Handle errors from gmail API.
    print(f"An error occurred: {error}")


if __name__ == "__main__":
  main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=755512977117-lgq0av2gtlel50htj9tehluieofs6avd.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A50787%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.compose+https%3A%2F%2Fmail.google.com%2F&state=AUBunuds1CScO2DnEMnjd3ZZcuXWw3&code_challenge=hxSUfR7SsGTpU3BelD0DAvWU1BFdyxhALUpbaHpLFos&code_challenge_method=S256&access_type=offline
# Labels:
# CHAT
# SENT
# INBOX
# IMPORTANT
# TRASH
# DRAFT
# SPAM
# CATEGORY_FORUMS
# CATEGORY_UPDATES
# CATEGORY_PERSONAL
# CATEGORY_PROMOTIONS
# CATEGORY_SOCIAL
# YELLOW_STAR
# STARRED
# UNREAD
# Neeta's Mail
# Sent Items
# Tickets
# Sudhir Shivram
# DJI
# MoragnStanly
# Deleted Items
# Medium
# DPS
# Lodha-Amara
# BNY
# HSBC
# Microsoft
# Junk E-mail
# UBS
# CITI

# %%
import base64
from email.message import EmailMessage

import google.auth
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError


def gmail_send_message():
  """Create and send an email message
  Print the returned  message id
  Returns: Message object, including message id

  Load pre-authorized user credentials from the environment.
  TODO(developer) - See https://developers.google.com/identity
  for guides on implementing OAuth2 for the application.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("gmail", "v1", credentials=creds)
    message = EmailMessage()

    message.set_content("This is automated draft mail")

    message["To"] = "brijeshdhaker@gmail.com"
    message["From"] = "brijeshdhaker@gmail.com"
    message["Subject"] = "Automated draft"

    # encoded message
    encoded_message = base64.urlsafe_b64encode(message.as_bytes()).decode()

    create_message = {"raw": encoded_message}
    # pylint: disable=E1101
    send_message = (
        service.users()
        .messages()
        .send(userId="me", body=create_message)
        .execute()
    )
    print(f'Message Id: {send_message["id"]}')
  except HttpError as error:
    print(f"An error occurred: {error}")
    send_message = None
  return send_message


if __name__ == "__main__":
  gmail_send_message()
# Out:
# Message Id: 19d5e2e584d8c6ce
